# %% [markdown]
# <a href="https://colab.research.google.com/github/daniela-6/Games/blob/main/corte_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

list = ["Piedra", "Papel", "Tijeras"]
aleatorio = random.choice(list)

print("Seleccione una opción (numero): ")
print("1: Piedra")
print("2: Papel")
print("3: Tijeras")

x = int(input("seleccione un numero: "))

if x == 1:
  elijeusuario = "Piedra"
elif x == 2:
  elijeusuario = "Papel"  
elif x == 3:
  elijeusuario = "Tijeras"
print("tu elijes: ", elijeusuario)

if aleatorio == 0: 
  print("Piedra")
elif aleatorio == 1:
  print("Papel")
elif aleatorio == 2:
  print("Tijeras")
if x == 1 and elijeusuario == "Papel":
  print("GANASTE")
elif x == 2 and elijeusuario == "Tijeras":
  print("GANASTE")
elif x == 3 and elijeusuario == "Piedra":
  print("GANASTE")
if x == elijeusuario: 
  print("EMPATE")
# Out:
# Seleccione una opción (numero):
# 1: Piedra
# 2: Papel
# 3: Tijeras
# seleccione un numero:  2
# tu elijes:  Papel
